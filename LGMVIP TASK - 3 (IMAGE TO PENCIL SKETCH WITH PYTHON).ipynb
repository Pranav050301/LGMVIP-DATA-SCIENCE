# %% [markdown]
# # LetsGrowMore
# Name: Pranav.M.Manjrekar
#
# Data Science Intern
#
# Task-3: IMAGE TO PENCIL SKETCH WITH PYTHON

# %% [markdown]
# # Importing libraries

# %%
import cv2

# %% [markdown]
# # Reading image file

# %%
image = cv2.imread("Ford_Mustang_Shelby_GT500.jpg")
#image

# %% [markdown]
# # To show or display image

# %%
cv2.imshow("Ford_Mustang_Shelby_GT500",image)

# %% [markdown]
# # Read the image in RGB format

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
img_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %% [markdown]
# # Create a new image by converting the original image to greyscale

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
gray_image
# Out:
# array([[ 58,  77, 105, ..., 199, 199, 199],
#        [ 71,  87, 109, ..., 199, 199, 199],
#        [ 92, 101, 113, ..., 199, 199, 199],
#        ...,
#        [119, 117, 117, ..., 139, 131, 124],
#        [112, 109, 108, ..., 138, 130, 122],
#        [107, 101,  99, ..., 136, 128, 121]], dtype=uint8)

# %%
plt.imshow(gray_image)

# %% [markdown]
# # Inverting grey image

# %%
inverted_image = 255 - gray_image
#inverted_image = cv2.bitwise_not(gray_image)
plt.imshow(inverted_image)

# %% [markdown]
# # Blur the image by using the Gaussian Function

# %%
blurred = cv2.GaussianBlur(inverted_image,(21, 21), 0)
plt.imshow(blurred)

# %% [markdown]
# # Invert the blurred image for final image(pencil sketch)

# %%
inverted_blurred = 255 - blurred
pencil_sketch = cv2.divide(gray_image, inverted_blurred, scale=256.0)
plt.imshow(pencil_sketch)

# %% [markdown]
# # Final Sketch

# %%
cv2.imshow("Ford_Mustang_Shelby_GT500", pencil_sketch)

# %% [markdown]
# # Original image and the pencil sketch

# %%
cv2.imshow("original image", image)
cv2.imshow("pencil_sketch", pencil_sketch)
