# %% [markdown]
# # LetsGrowMore
#
# Name: Pranav.M.Manjrekar
#
# Data Science Intern
#
# Task-2: Stock Market Prediction and Forecasting using Stacked LSTM
#
# Dataset:https://raw.githubusercontent.com/mwitiderrick/stockprice/master/NSE-TATAGLOBAL.csv

# %% [markdown]
# # Importing the Necessary Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler

# Ignoring warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Reading the Data

# %%
data_set = pd.read_csv('stock.csv')
data_set
# Out:
#             Date    Open    High     Low    Last   Close  \
# 0     2018-09-28  234.05  235.95  230.20  233.50  233.75
# 1     2018-09-27  234.55  236.80  231.10  233.80  233.25
# 2     2018-09-26  240.00  240.00  232.50  235.00  234.25
# 3     2018-09-25  233.30  236.75  232.00  236.25  236.10
# 4     2018-09-24  233.55  239.20  230.75  234.00  233.30
# ...          ...     ...     ...     ...     ...     ...
# 2030  2010-07-27  117.60  119.50  112.00  118.80  118.65
# 2031  2010-07-26  120.10  121.00  117.10  117.10  117.60
# 2032  2010-07-23  121.80  121.95  120.25  120.35  120.65
# 2033  2010-07-22  120.30  122.00  120.25  120.75  120.90
# 2034  2010-07-21  122.10  123.00  121.05  121.10  121.55
#
#       Total Trade Quantity  Turnover (Lacs)
# 0                  3069914          7162.35
# 1                  5082859         11859.95
# 2                  2240909          5248.60
# 3                  2349368          5503.90
# 4                  3423509          7999.55
# ...                    ...              ...
# 2030                586100           694.98
# 2031                658440           780.01
# 2032                281312           340.31
# 2033                293312           355.17
# 2034                658666           803.56
#
# [2035 rows x 8 columns]

# %% [markdown]
# # Exploring Data and Making required changes for better understanding

# %%
data_set.isnull().sum()
# No null values so we can proceed
# Out:
# Date                    0
# Open                    0
# High                    0
# Low                     0
# Last                    0
# Close                   0
# Total Trade Quantity    0
# Turnover (Lacs)         0
# dtype: int64

# %%
data_set['Date'] = pd.to_datetime(data_set['Date'])

# %%
df = data_set.sort_values('Date')
df.head()
# Out:
#            Date   Open    High     Low    Last   Close  Total Trade Quantity  \
# 2034 2010-07-21  122.1  123.00  121.05  121.10  121.55                658666
# 2033 2010-07-22  120.3  122.00  120.25  120.75  120.90                293312
# 2032 2010-07-23  121.8  121.95  120.25  120.35  120.65                281312
# 2031 2010-07-26  120.1  121.00  117.10  117.10  117.60                658440
# 2030 2010-07-27  117.6  119.50  112.00  118.80  118.65                586100
#
#       Turnover (Lacs)
# 2034           803.56
# 2033           355.17
# 2032           340.31
# 2031           780.01
# 2030           694.98

# %%
df.reset_index(inplace=True)

# %% [markdown]
# # Visualizing the Data

# %%
plt.plot(df['Close'])

# %%
df_close = df['Close']
df_close
# Out:
# 0       121.55
# 1       120.90
# 2       120.65
# 3       117.60
# 4       118.65
#          ...
# 2030    233.30
# 2031    236.10
# 2032    234.25
# 2033    233.25
# 2034    233.75
# Name: Close, Length: 2035, dtype: float64

# %% [markdown]
# # Feature Scaling

# %%
scaler = MinMaxScaler(feature_range=(0,1))

# %%
df_close = scaler.fit_transform(np.array(df_close).reshape(-1,1))
df_close
# Out:
# array([[0.16584967],
#        [0.16319444],
#        [0.1621732 ],
#        ...,
#        [0.62622549],
#        [0.62214052],
#        [0.62418301]])

# %% [markdown]
# # Splitting the data into training and test sets

# %%
training_size = int(len(df_close)*0.70)
test_size = len(df_close) - training_size
train, test = df_close[0: training_size,:], df_close[training_size : len(df_close),:1]

# %%
# Let us convert the array values previously calculated into a matrix
def create_mat(ds, time_step = 1):
    dataX, dataY = [],[]
    for i in range(len(ds)-time_step-1):
        a = ds[i:(i+time_step),0]
        dataX.append(a)
        dataY.append(ds[i + time_step, 0])
    return np.array(dataX), np.array(dataY)

# %%
time_step = 100
X_train, y_train = create_mat(train, time_step)
X_test, y_test = create_mat(test, time_step)

# %%
X_train.shape
# Out:
# (1323, 100)

# %%
y_train.shape
# Out:
# (1323,)

# %%
X_test.shape
# Out:
# (510, 100)

# %%
y_test.shape
# Out:
# (510,)

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1],1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %% [markdown]
# # Building the Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %%
model = Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(100,1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 100, 50)           10400
#
#  lstm_1 (LSTM)               (None, 100, 50)           20200
#
#  lstm_2 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, y_train, validation_split=0.1, epochs=60, batch_size=64, verbose = 1)
# Out:
# Epoch 1/60
# 19/19 [==============================] - 34s 743ms/step - loss: 0.0098 - val_loss: 0.0012
# Epoch 2/60
# 19/19 [==============================] - 8s 411ms/step - loss: 0.0020 - val_loss: 0.0013
# Epoch 3/60
# 19/19 [==============================] - 8s 411ms/step - loss: 9.8245e-04 - val_loss: 0.0012
# Epoch 4/60
# 19/19 [==============================] - 8s 438ms/step - loss: 8.3908e-04 - val_loss: 0.0011
# Epoch 5/60
# 19/19 [==============================] - 8s 440ms/step - loss: 8.0088e-04 - val_loss: 0.0011
# Epoch 6/60
# 19/19 [==============================] - 8s 438ms/step - loss: 7.7210e-04 - val_loss: 0.0010
# Epoch 7/60
# 19/19 [==============================] - 9s 469ms/step - loss: 7.4566e-04 - val_loss: 9.6849e-04
# Epoch 8/60
# 19/19 [==============================] - 8s 430ms/step - loss: 7.6385e-04 - val_loss: 9.2300e-04
# Epoch 9/60
# 19/19 [==============================] - 9s 467ms/step - loss: 7.1562e-04 - val_loss: 9.7380e-04
# Epoch 10/60
# 19/19 [==============================] - 8s 447ms/step - loss: 6.8630e-04 - val_loss: 8.6599e-04
# Epoch 11/60
# 19/19 [==============================] - 8s 447ms/step - loss: 6.8571e-04 - val_loss: 8.5584e-04
# Epoch 12/60
# 19/19 [==============================] - 8s 426ms/step - loss: 6.6119e-04 - val_loss: 7.8848e-04
# Epoch 13/60
# 19/19 [==============================] - 8s 421ms/step - loss: 6.2621e-04 - val_loss: 7.2480e-04
# Epoch 14/60
# 19/19 [==============================] - 8s 447ms/step - loss: 6.1567e-04 - val_loss: 7.2501e-04
# Epoch 15/60
# 19/19 [==============================] - 9s 457ms/step - loss: 6.0693e-04 - val_loss: 6.8311e-04
# Epoch 16/60
# 19/19 [==============================] - 9s 461ms/step - loss: 5.9137e-04 - val_loss: 6.8335e-04
# Epoch 17/60
# 19/19 [==============================] - 8s 436ms/step - loss: 5.7941e-04 - val_loss: 6.6117e-04
# Epoch 18/60
# 19/19 [==============================] - 9s 446ms/step - loss: 5.6588e-04 - val_loss: 6.1567e-04
# Epoch 19/60
# 19/19 [==============================] - 8s 434ms/step - loss: 5.5525e-04 - val_loss: 6.3221e-04
# Epoch 20/60
# 19/19 [==============================] - 10s 534ms/step - loss: 5.4171e-04 - val_loss: 5.9178e-04
# Epoch 21/60
# 19/19 [==============================] - 9s 457ms/step - loss: 5.1642e-04 - val_loss: 5.7944e-04
# Epoch 22/60
# 19/19 [==============================] - 9s 457ms/step - loss: 4.9958e-04 - val_loss: 5.6146e-04
# Epoch 23/60
# 19/19 [==============================] - 8s 424ms/step - loss: 4.9882e-04 - val_loss: 5.4607e-04
# Epoch 24/60
# 19/19 [==============================] - 8s 439ms/step - loss: 4.9034e-04 - val_loss: 5.8026e-04
# Epoch 25/60
# 19/19 [==============================] - 8s 447ms/step - loss: 4.7513e-04 - val_loss: 6.6137e-04
# Epoch 26/60
# 19/19 [==============================] - 9s 464ms/step - loss: 4.7620e-04 - val_loss: 4.7560e-04
# Epoch 27/60
# 19/19 [==============================] - 9s 472ms/step - loss: 5.2905e-04 - val_loss: 5.4236e-04
# Epoch 28/60
# 19/19 [==============================] - 9s 489ms/step - loss: 4.5149e-04 - val_loss: 4.5512e-04
# Epoch 29/60
# 19/19 [==============================] - 8s 437ms/step - loss: 4.2555e-04 - val_loss: 4.6197e-04
# Epoch 30/60
# 19/19 [==============================] - 8s 446ms/step - loss: 4.1735e-04 - val_loss: 4.3501e-04
# Epoch 31/60
# 19/19 [==============================] - 8s 426ms/step - loss: 3.9514e-04 - val_loss: 4.3014e-04
# Epoch 32/60
# 19/19 [==============================] - 8s 435ms/step - loss: 3.9412e-04 - val_loss: 3.8562e-04
# Epoch 33/60
# 19/19 [==============================] - 9s 483ms/step - loss: 3.8015e-04 - val_loss: 3.9200e-04
# Epoch 34/60
# 19/19 [==============================] - 9s 443ms/step - loss: 3.7662e-04 - val_loss: 3.5630e-04
# Epoch 35/60
# 19/19 [==============================] - 8s 418ms/step - loss: 3.5786e-04 - val_loss: 3.4428e-04
# Epoch 36/60
# 19/19 [==============================] - 8s 439ms/step - loss: 3.4607e-04 - val_loss: 4.5728e-04
# Epoch 37/60
# 19/19 [==============================] - 8s 427ms/step - loss: 3.5900e-04 - val_loss: 3.2803e-04
# Epoch 38/60
# 19/19 [==============================] - 8s 433ms/step - loss: 3.5347e-04 - val_loss: 3.0741e-04
# Epoch 39/60
# 19/19 [==============================] - 8s 442ms/step - loss: 3.2799e-04 - val_loss: 3.3809e-04
# Epoch 40/60
# 19/19 [==============================] - 8s 439ms/step - loss: 3.1815e-04 - val_loss: 2.9694e-04
# Epoch 41/60
# 19/19 [==============================] - 9s 465ms/step - loss: 3.1077e-04 - val_loss: 2.7874e-04
# Epoch 42/60
# 19/19 [==============================] - 8s 429ms/step - loss: 3.1089e-04 - val_loss: 2.9562e-04
# Epoch 43/60
# 19/19 [==============================] - 8s 451ms/step - loss: 3.0993e-04 - val_loss: 3.2263e-04
# Epoch 44/60
# 19/19 [==============================] - 8s 407ms/step - loss: 3.0098e-04 - val_loss: 2.5577e-04
# Epoch 45/60
# 19/19 [==============================] - 8s 442ms/step - loss: 3.1679e-04 - val_loss: 2.6439e-04
# Epoch 46/60
# 19/19 [==============================] - 9s 456ms/step - loss: 3.2267e-04 - val_loss: 2.4885e-04
# Epoch 47/60
# 19/19 [==============================] - 8s 419ms/step - loss: 2.7855e-04 - val_loss: 2.4186e-04
# Epoch 48/60
# 19/19 [==============================] - 8s 429ms/step - loss: 2.7164e-04 - val_loss: 3.0307e-04
# Epoch 49/60
# 19/19 [==============================] - 8s 435ms/step - loss: 2.6315e-04 - val_loss: 2.2491e-04
# Epoch 50/60
# 19/19 [==============================] - 8s 436ms/step - loss: 2.5297e-04 - val_loss: 2.1757e-04
# Epoch 51/60
# 19/19 [==============================] - 8s 429ms/step - loss: 2.4899e-04 - val_loss: 2.0838e-04
# Epoch 52/60
# 19/19 [==============================] - 9s 459ms/step - loss: 2.4941e-04 - val_loss: 2.1346e-04
# Epoch 53/60
# 19/19 [==============================] - 8s 398ms/step - loss: 2.3621e-04 - val_loss: 1.9651e-04
# Epoch 54/60
# 19/19 [==============================] - 8s 438ms/step - loss: 2.3547e-04 - val_loss: 2.0162e-04
# Epoch 55/60
# 19/19 [==============================] - 9s 463ms/step - loss: 2.1854e-04 - val_loss: 1.8776e-04
# Epoch 56/60
# 19/19 [==============================] - 9s 465ms/step - loss: 2.2153e-04 - val_loss: 1.8644e-04
# Epoch 57/60
# 19/19 [==============================] - 8s 420ms/step - loss: 2.2100e-04 - val_loss: 1.8065e-04
# Epoch 58/60
# 19/19 [==============================] - 8s 428ms/step - loss: 2.1949e-04 - val_loss: 1.7512e-04
# Epoch 59/60
# 19/19 [==============================] - 8s 446ms/step - loss: 2.1728e-04 - val_loss: 1.9696e-04
# Epoch 60/60
# 19/19 [==============================] - 8s 399ms/step - loss: 2.3136e-04 - val_loss: 2.3621e-04

# %%
predictions = model.predict(X_test)

# %%
# performing inverse transform on predictions
inv_predictions = scaler.inverse_transform(predictions)

# %%
inv_predictions
# Out:
# array([[143.95308 ],
#        [144.13766 ],
#        [143.24884 ],
#        [140.59703 ],
#        [138.89127 ],
#        [138.3478  ],
#        [139.54883 ],
#        [141.18912 ],
#        [141.65015 ],
#        [141.26881 ],
#        [140.94893 ],
#        [142.03844 ],
#        [142.82812 ],
#        [144.38164 ],
#        [146.57387 ],
#        [144.66306 ],
#        [142.17136 ],
#        [141.68901 ],
#        [142.32977 ],
#        [147.34875 ],
#        [151.92972 ],
#        [154.20824 ],
#        [154.4992  ],
#        [152.3028  ],
#        [151.90813 ],
#        [151.68738 ],
#        [152.18353 ],
#        [153.98909 ],
#        [154.86829 ],
#        [154.91904 ],
#        [155.26675 ],
#        [154.09724 ],
#        [150.83534 ],
#        [145.1368  ],
#        [141.65413 ],
#        [140.71959 ],
#        [141.01625 ],
#        [140.35698 ],
#        [138.09593 ],
#        [134.37015 ],
#        [131.69806 ],
#        [130.38246 ],
#        [128.30391 ],
#        [127.406975],
#        [125.39842 ],
#        [122.7732  ],
#        [121.91984 ],
#        [121.53598 ],
#        [121.70471 ],
#        [120.7766  ],
#        [119.83475 ],
#        [119.32199 ],
#        [118.468475],
#        [118.49194 ],
#        [119.69992 ],
#        [121.42154 ],
#        [123.32386 ],
#        [124.14658 ],
#        [123.941124],
#        [123.900444],
#        [124.01897 ],
#        [123.8778  ],
#        [124.08213 ],
#        [124.50782 ],
#        [124.77437 ],
#        [124.877396],
#        [124.72899 ],
#        [125.01454 ],
#        [125.4676  ],
#        [125.84309 ],
#        [125.16034 ],
#        [124.19787 ],
#        [122.864716],
#        [121.61103 ],
#        [120.31469 ],
#        [120.3626  ],
#        [120.92037 ],
#        [121.8725  ],
#        [122.95447 ],
#        [124.159836],
#        [125.2874  ],
#        [125.97816 ],
#        [126.39446 ],
#        [126.3887  ],
#        [126.19043 ],
#        [125.90827 ],
#        [126.61838 ],
#        [127.0104  ],
#        [127.96862 ],
#        [128.80873 ],
#        [129.25948 ],
#        [129.69061 ],
#        [130.59412 ],
#        [130.22917 ],
#        [129.68396 ],
#        [129.53406 ],
#        [129.66286 ],
#        [130.14636 ],
#        [131.04999 ],
#        [131.37555 ],
#        [131.61725 ],
#        [134.17746 ],
#        [138.60855 ],
#        [142.66924 ],
#        [144.48094 ],
#        [145.9357  ],
#        [146.05006 ],
#        [145.42047 ],
#        [144.07083 ],
#        [142.73126 ],
#        [141.21442 ],
#        [140.78273 ],
#        [141.24094 ],
#        [142.51003 ],
#        [143.71837 ],
#        [143.81313 ],
#        [142.99918 ],
#        [141.9509  ],
#        [140.91492 ],
#        [142.2152  ],
#        [143.37819 ],
#        [144.59633 ],
#        [145.34521 ],
#        [145.34105 ],
#        [144.4615  ],
#        [143.28949 ],
#        [141.1747  ],
#        [140.26744 ],
#        [140.95361 ],
#        [143.51065 ],
#        [146.04303 ],
#        [148.03    ],
#        [148.72809 ],
#        [147.42531 ],
#        [148.78825 ],
#        [151.02824 ],
#        [151.61656 ],
#        [151.78221 ],
#        [151.85701 ],
#        [151.7458  ],
#        [151.78934 ],
#        [152.4916  ],
#        [153.5824  ],
#        [154.5717  ],
#        [154.12904 ],
#        [153.30542 ],
#        [153.73526 ],
#        [154.01424 ],
#        [153.51257 ],
#        [152.44653 ],
#        [151.11533 ],
#        [151.06561 ],
#        [152.48822 ],
#        [153.64449 ],
#        [154.30922 ],
#        [154.34328 ],
#        [154.8488  ],
#        [154.73457 ],
#        [154.67438 ],
#        [156.5498  ],
#        [158.00981 ],
#        [158.11821 ],
#        [156.29442 ],
#        [154.53076 ],
#        [154.32176 ],
#        [155.34377 ],
#        [156.13857 ],
#        [155.88313 ],
#        [156.03925 ],
#        [156.35931 ],
#        [155.92296 ],
#        [153.11961 ],
#        [151.19243 ],
#        [150.05142 ],
#        [148.54344 ],
#        [146.28554 ],
#        [145.14354 ],
#        [146.53561 ],
#        [148.01117 ],
#        [148.74254 ],
#        [150.17651 ],
#        [152.53098 ],
#        [155.20827 ],
#        [156.81627 ],
#        [156.29779 ],
#        [155.94235 ],
#        [155.60309 ],
#        [155.3469  ],
#        [154.39578 ],
#        [155.34392 ],
#        [157.8327  ],
#        [160.23576 ],
#        [161.1043  ],
#        [160.08333 ],
#        [158.86122 ],
#        [158.19788 ],
#        [157.28539 ],
#        [155.17648 ],
#        [151.95688 ],
#        [150.46379 ],
#        [150.34404 ],
#        [151.70404 ],
#        [153.5292  ],
#        [154.06903 ],
#        [156.02693 ],
#        [156.77867 ],
#        [158.11516 ],
#        [162.80293 ],
#        [168.32565 ],
#        [173.29199 ],
#        [176.2535  ],
#        [176.17448 ],
#        [175.98622 ],
#        [174.56912 ],
#        [174.03873 ],
#        [172.71188 ],
#        [172.29765 ],
#        [171.82797 ],
#        [172.2603  ],
#        [173.56108 ],
#        [172.87376 ],
#        [171.88914 ],
#        [171.54497 ],
#        [170.6807  ],
#        [168.79599 ],
#        [168.06114 ],
#        [168.17906 ],
#        [170.35172 ],
#        [170.34642 ],
#        [167.33978 ],
#        [161.77342 ],
#        [161.43839 ],
#        [170.41864 ],
#        [186.50131 ],
#        [196.07222 ],
#        [198.45615 ],
#        [196.94536 ],
#        [191.20529 ],
#        [190.22324 ],
#        [191.19435 ],
#        [192.11719 ],
#        [191.37418 ],
#        [194.30502 ],
#        [198.12593 ],
#        [199.85481 ],
#        [197.31844 ],
#        [196.26543 ],
#        [201.64241 ],
#        [206.43904 ],
#        [208.32353 ],
#        [209.04471 ],
#        [210.38586 ],
#        [208.41252 ],
#        [208.88493 ],
#        [209.53143 ],
#        [211.43268 ],
#        [214.51259 ],
#        [214.74524 ],
#        [212.75081 ],
#        [204.88934 ],
#        [197.22023 ],
#        [199.46199 ],
#        [201.27626 ],
#        [204.07999 ],
#        [207.20703 ],
#        [208.67058 ],
#        [207.31999 ],
#        [207.87764 ],
#        [208.8526  ],
#        [208.39029 ],
#        [207.6446  ],
#        [207.9035  ],
#        [210.00378 ],
#        [210.61581 ],
#        [209.83882 ],
#        [209.51176 ],
#        [207.67734 ],
#        [205.1445  ],
#        [203.23691 ],
#        [206.65192 ],
#        [207.77747 ],
#        [209.54529 ],
#        [216.67041 ],
#        [224.98393 ],
#        [227.96964 ],
#        [226.8466  ],
#        [223.83394 ],
#        [221.47733 ],
#        [226.8704  ],
#        [226.24956 ],
#        [223.37987 ],
#        [231.88333 ],
#        [236.77138 ],
#        [235.29672 ],
#        [240.04582 ],
#        [246.5965  ],
#        [249.40724 ],
#        [253.59602 ],
#        [264.7946  ],
#        [269.07343 ],
#        [267.86804 ],
#        [266.389   ],
#        [268.8859  ],
#        [270.52658 ],
#        [277.87497 ],
#        [276.99832 ],
#        [278.72403 ],
#        [278.0569  ],
#        [274.16245 ],
#        [273.21906 ],
#        [271.02634 ],
#        [276.4542  ],
#        [283.30914 ],
#        [291.46875 ],
#        [286.13318 ],
#        [277.95566 ],
#        [275.52173 ],
#        [278.91565 ],
#        [284.49203 ],
#        [293.0495  ],
#        [295.6925  ],
#        [293.4422  ],
#        [293.085   ],
#        [295.81677 ],
#        [297.14398 ],
#        [297.90384 ],
#        [304.83856 ],
#        [305.7551  ],
#        [302.86838 ],
#        [301.5507  ],
#        [302.8096  ],
#        [304.54822 ],
#        [308.3892  ],
#        [308.1987  ],
#        [306.11578 ],
#        [304.76898 ],
#        [313.39966 ],
#        [315.86908 ],
#        [309.7183  ],
#        [304.39648 ],
#        [298.4671  ],
#        [299.71283 ],
#        [302.82617 ],
#        [302.77582 ],
#        [299.66016 ],
#        [298.01804 ],
#        [296.28732 ],
#        [297.2823  ],
#        [288.95694 ],
#        [282.95584 ],
#        [273.51218 ],
#        [269.58572 ],
#        [266.49808 ],
#        [275.26083 ],
#        [280.79245 ],
#        [278.3511  ],
#        [279.08383 ],
#        [277.54697 ],
#        [273.9234  ],
#        [270.12164 ],
#        [264.2963  ],
#        [259.28223 ],
#        [261.48862 ],
#        [261.7133  ],
#        [266.6673  ],
#        [271.125   ],
#        [272.3109  ],
#        [271.2623  ],
#        [269.46713 ],
#        [269.19043 ],
#        [268.7093  ],
#        [265.1908  ],
#        [266.69925 ],
#        [265.71335 ],
#        [269.81213 ],
#        [274.02383 ],
#        [274.89142 ],
#        [274.47034 ],
#        [269.00674 ],
#        [258.16135 ],
#        [255.3352  ],
#        [258.81772 ],
#        [259.0434  ],
#        [257.35    ],
#        [259.1081  ],
#        [261.4701  ],
#        [258.38376 ],
#        [267.34955 ],
#        [272.08023 ],
#        [267.94647 ],
#        [265.68555 ],
#        [265.79825 ],
#        [270.1227  ],
#        [271.26413 ],
#        [269.46823 ],
#        [268.34488 ],
#        [269.6339  ],
#        [273.61993 ],
#        [276.29373 ],
#        [278.43494 ],
#        [280.04053 ],
#        [280.14368 ],
#        [277.82285 ],
#        [276.37375 ],
#        [280.65768 ],
#        [285.03336 ],
#        [286.53458 ],
#        [289.57135 ],
#        [287.40143 ],
#        [281.08328 ],
#        [279.61008 ],
#        [285.64777 ],
#        [286.35916 ],
#        [286.327   ],
#        [281.6142  ],
#        [280.64587 ],
#        [260.16425 ],
#        [240.67784 ],
#        [236.97656 ],
#        [246.3654  ],
#        [251.17178 ],
#        [249.27817 ],
#        [247.96457 ],
#        [248.80086 ],
#        [251.503   ],
#        [254.25867 ],
#        [256.25607 ],
#        [254.13943 ],
#        [256.56262 ],
#        [262.0571  ],
#        [260.62253 ],
#        [252.67827 ],
#        [254.53926 ],
#        [260.33563 ],
#        [264.02914 ],
#        [264.1682  ],
#        [260.83762 ],
#        [261.3987  ],
#        [264.29996 ],
#        [271.12918 ],
#        [270.30292 ],
#        [269.39236 ],
#        [263.81598 ],
#        [256.85892 ],
#        [253.50177 ],
#        [257.06    ],
#        [262.15533 ],
#        [265.65292 ],
#        [264.47202 ],
#        [261.06473 ],
#        [262.8067  ],
#        [261.6217  ],
#        [271.06763 ],
#        [274.5774  ],
#        [268.85214 ],
#        [261.22147 ],
#        [265.16006 ],
#        [270.00174 ],
#        [268.0824  ],
#        [262.48047 ],
#        [256.00946 ],
#        [243.9706  ],
#        [242.64824 ],
#        [240.54646 ],
#        [235.98645 ],
#        [237.572   ],
#        [243.06514 ],
#        [247.18062 ],
#        [241.00014 ],
#        [236.23112 ],
#        [237.30942 ],
#        [239.47081 ],
#        [243.27565 ],
#        [237.83531 ],
#        [232.61737 ],
#        [231.11584 ],
#        [235.2547  ],
#        [237.4787  ],
#        [236.49924 ],
#        [235.61621 ],
#        [232.99634 ],
#        [232.06598 ],
#        [234.38213 ],
#        [237.39522 ],
#        [240.70285 ],
#        [243.00394 ],
#        [240.18036 ],
#        [234.07715 ],
#        [228.46887 ],
#        [231.15869 ],
#        [233.11238 ],
#        [234.12115 ],
#        [235.12285 ],
#        [234.25998 ],
#        [234.57034 ],
#        [226.89276 ],
#        [220.58342 ],
#        [218.76985 ],
#        [221.22162 ],
#        [223.12973 ],
#        [219.78224 ],
#        [220.54091 ],
#        [229.23659 ],
#        [236.3538  ],
#        [236.32513 ],
#        [233.04086 ],
#        [230.50542 ],
#        [229.2461  ],
#        [231.28107 ],
#        [232.379   ]], dtype=float32)

# %% [markdown]
# # Performance Metrics

# %% [markdown]
# # Mean Square error

# %%
import math
from sklearn.metrics import mean_squared_error

# %%
mse = math.sqrt(mean_squared_error(y_test, predictions))
print("The Mean Squared Error for above model is:", mse)
# Out:
# The Mean Squared Error for above model is: 0.02445620562826742

# %% [markdown]
# # Conclusion: Hence, we can conclude that the mean squared error is low and is 0.02445620562826742
